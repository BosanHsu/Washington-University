# %%
import numpy as np 
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('airbnb-listings.csv', sep=',')
df.head()
# Out:
# C:\Users\hsupo\AppData\Local\Temp\ipykernel_43176\4266839384.py:1: DtypeWarning: Columns (0,2,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('airbnb-listings.csv', sep=',')
#          ID                            Listing Url       Scrape ID  \
# 0   4008728   https://www.airbnb.com/rooms/4008728  20170402075052
# 1   7778612   https://www.airbnb.com/rooms/7778612  20170402075052
# 2   8264596   https://www.airbnb.com/rooms/8264596  20170402075052
# 3   2180729   https://www.airbnb.com/rooms/2180729  20170402075052
# 4  14463171  https://www.airbnb.com/rooms/14463171  20170402075052
#
#   Last Scraped                                    Name  \
# 0   2017-04-02     Luxurious 3 bedroom, centrum, 180m2
# 1   2017-04-02         Luxury apartment in city centre
# 2   2017-04-02        Cosy apartment across Vondelpark
# 3   2017-04-02        Spacious City Apartment Oud-West
# 4   2017-04-02  Cosy Studio Apartment Center Amsterdam
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494954 entries, 0 to 494953
# Data columns (total 89 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ID                              494954 non-null  object
#  1   Listing Url                     494954 non-null  object
#  2   Scrape ID                       494954 non-null  object
#  3   Last Scraped                    494953 non-null  object
#  4   Name                            494536 non-null  object
#  5   Summary                         478753 non-null  object
#  6   Space                           347018 non-null  object
#  7   Description                     494794 non-null  object
#  8   Experiences Offered             494954 non-null  object
#  9   Neighborhood Overview           291604 non-null  object
#  10  Notes                           197590 non-null  object
#  11  Transit                         303786 non-null  object
# ...

# %%
df.describe()
# Out:
#             Host ID  Host Response Rate  Host Listings Count  \
# count  4.949540e+05       379884.000000        494449.000000
# mean   3.234417e+07           93.376549             9.549721
# std    3.172156e+07           17.592441            57.199523
# min    1.900000e+01            0.000000             0.000000
# 25%    6.886060e+06           98.000000             1.000000
# 50%    2.188181e+07          100.000000             1.000000
# 75%    4.792177e+07          100.000000             3.000000
# max    1.350885e+08          100.000000          1114.000000
#
#        Host Total Listings Count       Latitude      Longitude   Accommodates  \
# count              494448.000000  494953.000000  494953.000000  494891.000000
# mean                    9.549738      38.042292     -15.020974       3.311584
# std                    57.199579      22.941429      70.364294       2.094052
# min                     0.000000     -38.224427    -123.218712       1.000000
# ...

# %%
selected_columns = ['ID', 'Name', 'Neighborhood Overview', 'Transit', 'Host ID', 'Host Name', 'Host Since', 'Host About', 'Host Response Time', 'Host Response Rate', 'Street', 'Neighbourhood', 'City', 'Zipcode', 'Country', 'Latitude', 'Longitude', 'Property Type', 'Accommodates', 'Bathrooms', 'Bedrooms', 'Beds', 'Bed Type', 'Amenities', 'Price', 'Guests Included', 'Number of Reviews', 'Last Review', 'Review Scores Rating', 'Review Scores Cleanliness', 'Review Scores Location', 'Cancellation Policy', 'Geolocation']
df_selected = df.loc[:, selected_columns]
df_selected.head(5)
# Out:
#          ID                                    Name  \
# 0   4008728     Luxurious 3 bedroom, centrum, 180m2
# 1   7778612         Luxury apartment in city centre
# 2   8264596        Cosy apartment across Vondelpark
# 3   2180729        Spacious City Apartment Oud-West
# 4  14463171  Cosy Studio Apartment Center Amsterdam
#
#                                Neighborhood Overview  \
# 0  There is a wide variety of cafes and restauran...
# 1  Within a few minutes walking you'll be in the ...
# 2                                                NaN
# 3  The 85 m2 apartment is located on a quiet stre...
# 4                                                NaN
#
#                                              Transit   Host ID Host Name  \
# 0                                                NaN  20786453    Lithal
# 1       Public transport is very close  - 100 meters  11964927      Hein
# 2                                                NaN  23669273  Matthieu
# ...

# %%
df_selected.to_csv('airbnb_listings_selected.csv', index=False)
